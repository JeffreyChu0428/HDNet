# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from typing import Union, List, Optional
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from torchhd.embeddings import Projection
from torchhd.models import Centroid

# %%
class PTBXL_Dataset(Dataset):
    """
    A PyTorch Dataset for ECG samples grouped by subject (PTB-XL).

    Args:
        data_path (str): Path to the .pt file with data grouped by subject.
        subject_ids (Union[float, List[float], None]): Subject(s) to include. If None, uses all subjects.
        split (str): 'train', 'test', or None — whether to return a subset.
        test_ratio (float): Proportion to reserve for test split (if split is specified).
        random_seed (int): Random seed for reproducibility.
    """
    def __init__(
        self,
        data_path: str,
        subject_ids: Optional[Union[float, List[float]]] = None,
        split: Optional[str] = None,
        test_ratio: float = 0.2,
        val_ratio: float = 0.2,
        random_seed: int = 42
    ):
        assert split in [None, 'train', 'val', 'test'], "split must be None, 'train', 'val', or 'test'"

        raw_data = torch.load(data_path)
        all_subject_data = raw_data['data_by_subject']
        self.label_encoder = raw_data['label_encoder']
        # label index: [0:'AFIB' 1:'NORM' 2:'PAC' 3:'PVC' 4:'SBRAD' 5:'STACH']

        # Normalize subject_ids to list
        if subject_ids is None:
            selected_subjects = list(all_subject_data.keys())
        elif isinstance(subject_ids, float):
            selected_subjects = [subject_ids]
        else:
            selected_subjects = subject_ids

        # Collect all (x, y) pairs per subject
        all_samples = []

        for sid in selected_subjects:
            subject_data = all_subject_data[sid]
            x_list = subject_data['x']
            y_list = subject_data['y']
            samples = list(zip(x_list, y_list))
            all_samples.extend(samples)

        # Split based on sample count
        if split is not None:
            stratify_labels = [int(y) for _, y in all_samples]

            # First split into temp (train+val) and test
            temp_idx, test_idx = train_test_split(
                range(len(all_samples)),
                test_size=test_ratio,
                random_state=random_seed,
                stratify=stratify_labels
            )

            temp_samples = [all_samples[i] for i in temp_idx]
            temp_labels = [int(y) for _, y in temp_samples]

            # Now split temp into train and val
            train_idx, val_idx = train_test_split(
                range(len(temp_samples)),
                test_size=val_ratio,
                random_state=random_seed,
                stratify=temp_labels
            )

            if split == 'train':
                indices = [temp_idx[i] for i in train_idx]
            elif split == 'val':
                indices = [temp_idx[i] for i in val_idx]
            elif split == 'test':
                indices = test_idx

            self.samples = [all_samples[i] for i in indices]
        else:
            self.samples = all_samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y = self.samples[idx]
        return x.unsqueeze(0), y  # Add channel dimension: (1, 2500)

# %%
class ECGNet(nn.Module):
    def __init__(self):
        super(ECGNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv1d(1, 8, 16, stride=2, padding=7),
            nn.ReLU(),
            # nn.BatchNorm1d(8),
            nn.MaxPool1d(kernel_size=8, stride=4),

            nn.Conv1d(8, 12, 12, padding=5, stride=2),
            nn.ReLU(),
            # nn.BatchNorm1d(16),
            nn.MaxPool1d(4, stride=2),

            nn.Conv1d(12, 32, 9, stride=1, padding=4),
            nn.ReLU(),
            nn.MaxPool1d(5, stride=2),

            nn.Conv1d(32, 64, 7, stride=1, padding=3),
            nn.ReLU(),
            nn.MaxPool1d(4, stride=2),

            nn.Conv1d(64, 64, 5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(2, 2),

            nn.Conv1d(64, 64, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(2, 2),

            nn.Conv1d(64, 72, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(2, 2),
        )
        self.classifier = torch.nn.Sequential(
            nn.Linear(in_features=144, out_features=64),
            nn.ReLU(),
            nn.Dropout(p=.1),
            nn.Linear(in_features=64, out_features=6),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view((x.size(0), -1))
        x = self.classifier(x)
        return x

# %%
# Step 1: Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Step 2: Prepare dataset and dataloader
batch_size = 50
# Load dataset
train_dataset = PTBXL_Dataset("./datasets/ptbxl_all_data.pt", split='train')
val_dataset = PTBXL_Dataset("./datasets/ptbxl_all_data.pt", split='val')
test_dataset = PTBXL_Dataset("./datasets/ptbxl_all_data.pt", split='test')

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Using device: cpu

# %%
print(train_dataset.label_encoder.classes_)
# Out:
# ['NORM' 'AFIB' 'PAC' 'PVC' 'SBRAD' 'STACH']

# %%
# Step 3: Initialize model
model = ECGNet().to(device)

# Step 4: Define loss function and optimizer
y_train = [train_dataset[i][1].item() if torch.is_tensor(train_dataset[i][1]) else train_dataset[i][1] 
           for i in range(len(train_dataset))]
class_counts = np.bincount(y_train)
weights = 1. / torch.tensor(class_counts, dtype=torch.float)
criterion = nn.CrossEntropyLoss(weight=weights.to(device))
optimizer = optim.Adam(model.parameters(), lr=1e-3)

best_val_acc = 0.0
best_model_path = "./models/ECGNet_weightedLoss.pth"

# Step 5: Training loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    all_preds = []
    all_labels = []

    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)  # shape: (batch, 17)

        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y_batch.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    print(f"[Epoch {epoch+1}] Loss: {epoch_loss:.4f} | Train Accuracy: {acc:.4f}")

    model.eval()
    val_preds, val_labels = [], []
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val = X_val.to(device)
            y_val = y_val.to(device)
            outputs = model(X_val)
            preds = torch.argmax(outputs, dim=1)
            val_preds.extend(preds.cpu().numpy())
            val_labels.extend(y_val.cpu().numpy())
    
    val_acc = accuracy_score(val_labels, val_preds)
    print(f"Validation Accuracy: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model updated")

print(f"Best model Validation Accuracy: {best_val_acc:.4f})")
# Out:
# [Epoch 1] Loss: 251.8884 | Train Accuracy: 0.5463
# Validation Accuracy: 0.7905
# Best model updated
# [Epoch 2] Loss: 199.8012 | Train Accuracy: 0.6258
# Validation Accuracy: 0.6160
# [Epoch 3] Loss: 165.7687 | Train Accuracy: 0.6710
# Validation Accuracy: 0.8190
# Best model updated
# [Epoch 4] Loss: 154.8933 | Train Accuracy: 0.6850
# Validation Accuracy: 0.7476
# [Epoch 5] Loss: 141.1387 | Train Accuracy: 0.7301
# Validation Accuracy: 0.7995
# [Epoch 6] Loss: 138.6201 | Train Accuracy: 0.7634
# Validation Accuracy: 0.8429
# Best model updated
# [Epoch 7] Loss: 118.9993 | Train Accuracy: 0.7915
# Validation Accuracy: 0.8379
# [Epoch 8] Loss: 111.8131 | Train Accuracy: 0.8075
# Validation Accuracy: 0.8574
# Best model updated
# [Epoch 9] Loss: 102.7366 | Train Accuracy: 0.8117
# Validation Accuracy: 0.7975
# [Epoch 10] Loss: 101.2746 | Train Accuracy: 0.8139
# Validation Accuracy: 0.8434
# [Epoch 11] Loss: 94.6429 | Train Accuracy: 0.8077
# Validation Accuracy: 0.8559
# [Epoch 12] Loss: 87.7973 | Train Accuracy: 0.8206
# Validation Accuracy: 0.6314
# [Epoch 13] Loss: 84.8912 | Train Accuracy: 0.8243
# Validation Accuracy: 0.8055
# [Epoch 14] Loss: 74.7737 | Train Accuracy: 0.8330
# Validation Accuracy: 0.7920
# [Epoch 15] Loss: 73.5093 | Train Accuracy: 0.8419
# Validation Accuracy: 0.8673
# Best model updated
# [Epoch 16] Loss: 64.9905 | Train Accuracy: 0.8543
# Validation Accuracy: 0.8524
# [Epoch 17] Loss: 65.0905 | Train Accuracy: 0.8398
# Validation Accuracy: 0.8529
# [Epoch 18] Loss: 66.7959 | Train Accuracy: 0.8410
# Validation Accuracy: 0.8279
# [Epoch 19] Loss: 61.0211 | Train Accuracy: 0.8323
# Validation Accuracy: 0.8274
# [Epoch 20] Loss: 55.9090 | Train Accuracy: 0.8585
# Validation Accuracy: 0.7761
# [Epoch 21] Loss: 52.5571 | Train Accuracy: 0.8590
# Validation Accuracy: 0.8773
# Best model updated
# [Epoch 22] Loss: 58.0745 | Train Accuracy: 0.8556
# Validation Accuracy: 0.8010
# [Epoch 23] Loss: 50.7985 | Train Accuracy: 0.8618
# Validation Accuracy: 0.8633
# [Epoch 24] Loss: 49.2890 | Train Accuracy: 0.8414
# Validation Accuracy: 0.8768
# [Epoch 25] Loss: 48.1312 | Train Accuracy: 0.8664
# Validation Accuracy: 0.8479
# [Epoch 26] Loss: 39.4234 | Train Accuracy: 0.8809
# Validation Accuracy: 0.8554
# [Epoch 27] Loss: 49.5012 | Train Accuracy: 0.8526
# Validation Accuracy: 0.8658
# [Epoch 28] Loss: 43.3012 | Train Accuracy: 0.8681
# Validation Accuracy: 0.8618
# [Epoch 29] Loss: 43.9085 | Train Accuracy: 0.8676
# Validation Accuracy: 0.8768
# [Epoch 30] Loss: 38.6199 | Train Accuracy: 0.8797
# Validation Accuracy: 0.8065
# [Epoch 31] Loss: 36.0537 | Train Accuracy: 0.8758
# Validation Accuracy: 0.8334
# [Epoch 32] Loss: 39.4387 | Train Accuracy: 0.8754
# Validation Accuracy: 0.8953
# Best model updated
# [Epoch 33] Loss: 37.0844 | Train Accuracy: 0.8717
# Validation Accuracy: 0.8898
# [Epoch 34] Loss: 43.4927 | Train Accuracy: 0.8778
# Validation Accuracy: 0.7870
# [Epoch 35] Loss: 36.3926 | Train Accuracy: 0.8652
# Validation Accuracy: 0.8015
# [Epoch 36] Loss: 27.0637 | Train Accuracy: 0.8878
# Validation Accuracy: 0.8464
# [Epoch 37] Loss: 33.5611 | Train Accuracy: 0.8661
# Validation Accuracy: 0.8673
# [Epoch 38] Loss: 26.6870 | Train Accuracy: 0.8944
# Validation Accuracy: 0.8748
# [Epoch 39] Loss: 22.0865 | Train Accuracy: 0.8947
# Validation Accuracy: 0.8683
# [Epoch 40] Loss: 20.4043 | Train Accuracy: 0.9065
# Validation Accuracy: 0.8579
# [Epoch 41] Loss: 19.0501 | Train Accuracy: 0.9113
# Validation Accuracy: 0.8773
# [Epoch 42] Loss: 48.3290 | Train Accuracy: 0.8768
# Validation Accuracy: 0.7322
# [Epoch 43] Loss: 36.6332 | Train Accuracy: 0.8783
# Validation Accuracy: 0.8728
# [Epoch 44] Loss: 29.2429 | Train Accuracy: 0.8956
# Validation Accuracy: 0.8589
# [Epoch 45] Loss: 32.4753 | Train Accuracy: 0.8842
# Validation Accuracy: 0.8788
# [Epoch 46] Loss: 23.0948 | Train Accuracy: 0.8934
# Validation Accuracy: 0.8000
# [Epoch 47] Loss: 24.2879 | Train Accuracy: 0.8949
# Validation Accuracy: 0.8883
# [Epoch 48] Loss: 25.8679 | Train Accuracy: 0.8843
# Validation Accuracy: 0.8743
# [Epoch 49] Loss: 27.0486 | Train Accuracy: 0.8854
# Validation Accuracy: 0.8738
# [Epoch 50] Loss: 23.2245 | Train Accuracy: 0.8980
# Validation Accuracy: 0.8678
# [Epoch 51] Loss: 41.3234 | Train Accuracy: 0.8678
# Validation Accuracy: 0.8544
# [Epoch 52] Loss: 25.3807 | Train Accuracy: 0.8860
# Validation Accuracy: 0.8738
# [Epoch 53] Loss: 19.7838 | Train Accuracy: 0.9106
# Validation Accuracy: 0.8983
# Best model updated
# [Epoch 54] Loss: 14.0171 | Train Accuracy: 0.9272
# Validation Accuracy: 0.8778
# [Epoch 55] Loss: 18.8290 | Train Accuracy: 0.9131
# Validation Accuracy: 0.8439
# [Epoch 56] Loss: 15.1397 | Train Accuracy: 0.9246
# Validation Accuracy: 0.8828
# [Epoch 57] Loss: 16.1045 | Train Accuracy: 0.9157
# Validation Accuracy: 0.8748
# [Epoch 58] Loss: 15.6010 | Train Accuracy: 0.9198
# Validation Accuracy: 0.8973
# [Epoch 59] Loss: 15.4217 | Train Accuracy: 0.9174
# Validation Accuracy: 0.8863
# [Epoch 60] Loss: 14.6920 | Train Accuracy: 0.9228
# Validation Accuracy: 0.8908
# [Epoch 61] Loss: 16.7653 | Train Accuracy: 0.9117
# Validation Accuracy: 0.8948
# [Epoch 62] Loss: 15.9955 | Train Accuracy: 0.9274
# Validation Accuracy: 0.8658
# [Epoch 63] Loss: 11.0901 | Train Accuracy: 0.9374
# Validation Accuracy: 0.9037
# Best model updated
# [Epoch 64] Loss: 56.2561 | Train Accuracy: 0.8456
# Validation Accuracy: 0.8599
# [Epoch 65] Loss: 29.8405 | Train Accuracy: 0.8954
# Validation Accuracy: 0.8309
# [Epoch 66] Loss: 20.3975 | Train Accuracy: 0.9098
# Validation Accuracy: 0.8738
# [Epoch 67] Loss: 17.0827 | Train Accuracy: 0.9204
# Validation Accuracy: 0.8808
# [Epoch 68] Loss: 11.6465 | Train Accuracy: 0.9309
# Validation Accuracy: 0.8828
# [Epoch 69] Loss: 10.7237 | Train Accuracy: 0.9350
# Validation Accuracy: 0.8918
# [Epoch 70] Loss: 9.2662 | Train Accuracy: 0.9435
# Validation Accuracy: 0.9027
# [Epoch 71] Loss: 9.0914 | Train Accuracy: 0.9473
# Validation Accuracy: 0.8913
# [Epoch 72] Loss: 26.2422 | Train Accuracy: 0.9189
# Validation Accuracy: 0.8863
# [Epoch 73] Loss: 12.6320 | Train Accuracy: 0.9349
# Validation Accuracy: 0.8943
# [Epoch 74] Loss: 39.4872 | Train Accuracy: 0.9031
# Validation Accuracy: 0.8658
# [Epoch 75] Loss: 17.2346 | Train Accuracy: 0.9204
# Validation Accuracy: 0.8993
# [Epoch 76] Loss: 21.9774 | Train Accuracy: 0.9253
# Validation Accuracy: 0.8938
# [Epoch 77] Loss: 10.8174 | Train Accuracy: 0.9418
# Validation Accuracy: 0.9017
# [Epoch 78] Loss: 9.7677 | Train Accuracy: 0.9454
# Validation Accuracy: 0.9027
# [Epoch 79] Loss: 12.7664 | Train Accuracy: 0.9465
# Validation Accuracy: 0.8185
# [Epoch 80] Loss: 22.4901 | Train Accuracy: 0.9132
# Validation Accuracy: 0.8873
# [Epoch 81] Loss: 11.0421 | Train Accuracy: 0.9328
# Validation Accuracy: 0.9027
# [Epoch 82] Loss: 13.7001 | Train Accuracy: 0.9323
# Validation Accuracy: 0.8913
# [Epoch 83] Loss: 13.1534 | Train Accuracy: 0.9403
# Validation Accuracy: 0.8878
# [Epoch 84] Loss: 10.0096 | Train Accuracy: 0.9499
# Validation Accuracy: 0.9012
# [Epoch 85] Loss: 14.5489 | Train Accuracy: 0.9309
# Validation Accuracy: 0.8728
# [Epoch 86] Loss: 41.1210 | Train Accuracy: 0.8732
# Validation Accuracy: 0.8733
# [Epoch 87] Loss: 15.4179 | Train Accuracy: 0.9238
# Validation Accuracy: 0.8913
# [Epoch 88] Loss: 8.2652 | Train Accuracy: 0.9505
# Validation Accuracy: 0.9007
# [Epoch 89] Loss: 7.6423 | Train Accuracy: 0.9551
# Validation Accuracy: 0.8838
# [Epoch 90] Loss: 12.0459 | Train Accuracy: 0.9374
# Validation Accuracy: 0.8778
# [Epoch 91] Loss: 11.8269 | Train Accuracy: 0.9495
# Validation Accuracy: 0.9047
# Best model updated
# [Epoch 92] Loss: 8.9593 | Train Accuracy: 0.9551
# Validation Accuracy: 0.8938
# [Epoch 93] Loss: 9.8004 | Train Accuracy: 0.9514
# Validation Accuracy: 0.8728
# [Epoch 94] Loss: 7.8116 | Train Accuracy: 0.9540
# Validation Accuracy: 0.8903
# [Epoch 95] Loss: 6.3592 | Train Accuracy: 0.9616
# Validation Accuracy: 0.9002
# [Epoch 96] Loss: 6.4644 | Train Accuracy: 0.9681
# Validation Accuracy: 0.8020
# [Epoch 97] Loss: 44.1415 | Train Accuracy: 0.8915
# Validation Accuracy: 0.8653
# [Epoch 98] Loss: 18.4636 | Train Accuracy: 0.9275
# Validation Accuracy: 0.8808
# [Epoch 99] Loss: 14.9801 | Train Accuracy: 0.9381
# Validation Accuracy: 0.8628
# [Epoch 100] Loss: 10.2463 | Train Accuracy: 0.9486
# Validation Accuracy: 0.8948
# Best model Validation Accuracy: 0.9047)

# %%
def extract_features(x, model):
    with torch.no_grad():
        features = model.features(x)         # → shape: (1, C, L)
        return features.view(1, -1)          # → shape: (1, 216)

# %% [markdown]
# HDC

# %%
model = ECGNet().to(device)
model.load_state_dict(torch.load("./models/ECGNet_weightedLoss.pth"))
model.eval()

HD_DIM = 10000
FEATURE_DIM = 144  # output of CNN before classifier

# Create projection layer
projection = Projection(in_features=FEATURE_DIM, out_features=HD_DIM)

# Create an HDC classifier (e.g., centroid-based)
num_classes = 6
hd_classifier = Centroid(HD_DIM, num_classes)

for idx in range(val_dataset.__len__()):
    x, y = val_dataset.__getitem__(idx)
    label = y.item()

    x = x.unsqueeze(0).to(device)  # shape: (1, 1, 3600)
    y = y.unsqueeze(0).to(device)

    feat = extract_features(x, model)     # → shape: (1, 216)
    hv = projection(feat)          # → shape: (1, 10000)

    hd_classifier.add(hv, y)       # add to HDC class prototype

# Normalize after training
hd_classifier.normalize()

# %%
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for idx in range(test_dataset.__len__()):
        x, y = test_dataset.__getitem__(idx)
        x = x.unsqueeze(0).to(device)  # shape: (1, 1, 3600)
        y = y.item()

        feats = extract_features(x, model)   # shape: (1, 216)
        hv = projection(feats)              # shape: (1, 10000)
        out = hd_classifier(hv)             # shape: (1, num_classes)

        pred = out.argmax(dim=1).item()

        all_preds.append(pred)
        all_labels.append(y)

print(classification_report(all_labels, all_preds, target_names=['NORM', 'AFIB', 'PAC', 'PVC', 'SBRAD', 'STACH']))
# precision(TP/TP+FP) important for NORM class, and recall(TP/TP+FN) for the rest
# Out:
#               precision    recall  f1-score   support
#
#         NORM       0.99      0.88      0.93      1849
#         AFIB       0.85      0.87      0.86       252
#          PAC       0.34      0.46      0.39        46
#          PVC       0.80      0.82      0.81       209
#        SBRAD       0.26      0.83      0.39        54
#        STACH       0.58      0.86      0.69        97
#
#     accuracy                           0.87      2507
#    macro avg       0.63      0.79      0.68      2507
# weighted avg       0.91      0.87      0.88      2507

# %%
# Compute confusion matrix
cm = confusion_matrix(all_labels, all_preds)
class_names = ['NORM', 'AFIB', 'PAC', 'PVC', 'SBRAD', 'STACH']

# Normalize
cm_normalized = np.divide(
    cm.astype('float'),
    cm.sum(axis=1)[:, np.newaxis],
    out=np.zeros_like(cm, dtype=float),
    where=cm.sum(axis=1)[:, np.newaxis] != 0
)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Raw confusion matrix
disp1 = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp1.plot(ax=ax1, cmap='Blues', xticks_rotation='vertical', colorbar=True)
ax1.set_title("Confusion Matrix")

# Normalized confusion matrix
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_names)
disp2.plot(ax=ax2, cmap='Blues', xticks_rotation='vertical', values_format=".2f", colorbar=True)
ax2.set_title("Normalized Confusion Matrix")

plt.tight_layout()
plt.show()

# %% [markdown]
# ECGNet

# %%
model = ECGNet().to(device)
model.load_state_dict(torch.load("./models/ECGNet_weightedLoss.pth"))
model.eval()
test_preds, test_labels = [], []
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test = X_test.to(device)
        y_test = y_test.to(device)
        outputs = model(X_test)
        preds = torch.argmax(outputs, dim=1)
        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(y_test.cpu().numpy())

print(classification_report(test_labels, test_preds, target_names=['NORM', 'AFIB', 'PAC', 'PVC', 'SBRAD', 'STACH']))
# Out:
#               precision    recall  f1-score   support
#
#         NORM       0.98      0.93      0.95      1849
#         AFIB       0.83      0.89      0.86       252
#          PAC       0.44      0.37      0.40        46
#          PVC       0.79      0.82      0.81       209
#        SBRAD       0.43      0.63      0.51        54
#        STACH       0.59      0.86      0.70        97
#
#     accuracy                           0.90      2507
#    macro avg       0.68      0.75      0.71      2507
# weighted avg       0.91      0.90      0.90      2507

# %%
# Compute confusion matrix
cm = confusion_matrix(test_labels, test_preds)
class_names = ['NORM', 'AFIB', 'PAC', 'PVC', 'SBRAD', 'STACH']

# Normalize
cm_normalized = np.divide(
    cm.astype('float'),
    cm.sum(axis=1)[:, np.newaxis],
    out=np.zeros_like(cm, dtype=float),
    where=cm.sum(axis=1)[:, np.newaxis] != 0
)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Raw confusion matrix
disp1 = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp1.plot(ax=ax1, cmap='Blues', xticks_rotation='vertical', colorbar=True)
ax1.set_title("Confusion Matrix")

# Normalized confusion matrix
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_names)
disp2.plot(ax=ax2, cmap='Blues', xticks_rotation='vertical', values_format=".2f", colorbar=True)
ax2.set_title("Normalized Confusion Matrix")

plt.tight_layout()
plt.show()
